# %% [markdown]
# # Download data
# This notebook downloads the data from the internet with 'wget' and stores it in the folder 'PNAS'.

# %%
#imports
import os
import zipfile

# %%
download_link = r"https://www.repository.cam.ac.uk/bitstream/handle/1810/262530/PNAS.zip?sequence=4&isAllowed=y"
os.system('wget -O datazip.zip ' + download_link)
# Out:
# ....... ..........  0% 1.33M 72m7s
#   4500K .......... .......... .......... .......... ..........  0% 2.45M 71m42s
#   4550K .......... .......... .......... .......... ..........  0% 2.54M 71m16s
#   4600K .......... .......... .......... .......... ..........  0% 1.32M 71m11s
#   4650K .......... .......... .......... .......... .........
# 0
# --2021-11-24 09:08:42--  https://www.repository.cam.ac.uk/bitstream/handle/1810/262530/PNAS.zip?sequence=4
# .  0% 2.29M 70m49s
#   4700K .......... .....Resolving www.repository.cam.ac.uk (www.repository.cam.ac.uk)... 131.111.98.67
# Connecting to www.repository.cam.ac.uk (www.repository.cam.ac.uk)|131.111.98.67|:443... ..... .......... .......... ..........  0% 3.16M 70m21s
#   4750K .......... .......... .......... .......... .....connected.
# .....  0% 1.39M 70m14s
#   4800K .......... .......... .......... .......... ..........  0% 45.0M 69m32s
#   4850K .......... .......... .......... .......... ..........  0% 1.39M 69m26s
# ...

# %%
with zipfile.ZipFile('datazip.zip', 'r') as zip_ref:
    zip_ref.extractall('data')

# %%
os.system('rm datazip.zip')
# Out:
# 0
