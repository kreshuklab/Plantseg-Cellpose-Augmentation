# %%
import skimage.io
import h5py
import numpy as np
import matplotlib.pyplot as plt
import jview
import os
# Out:
# Failed to start the Kernel.
#
# Failed to connect to Jupyter notebook.
#
# http://localhost:8888/
#
# TypeError: Cannot read property 'makeSettings' of undefined.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
dir_path = '/scratch/ottosson/tests/cellpose_augmentations/unit/'
with open(os.path.join(dir_path,'train_data.npy' ), 'rb') as f:
    raw = np.load(f)
with open(os.path.join(dir_path,'train_labels.npy' ), 'rb') as f:
    label = np.load(f)
with open(os.path.join(dir_path,'t_train_data.npy' ), 'rb') as f:
    t_raw = np.load(f)
with open(os.path.join(dir_path,'t_train_labels.npy' ), 'rb') as f:
    t_label= np.load(f)

# %%
jview.describe(raw,'raw')
jview.describe(label,'label')
jview.describe(t_raw,'Transofrmed raw')
jview.describe(t_label,'Transformed label')
#jview.describe(pred,'pred')
# Out:
# raw
# 	dtype: float32
# 	shape: (2, 400, 400)
# 	min: 0.0
# 	mean: 0.07323431968688965
# 	max: 2.270270347595215
# label
# 	dtype: float32
# 	shape: (4, 400, 400)
# 	min: -1.0
# 	mean: 3.799548864364624
# 	max: 112.0
# Transofrmed raw
# 	dtype: float32
# 	shape: (2, 400, 400)
# 	min: 0.0
# 	mean: 0.07323433458805084
# 	max: 2.270270347595215
# Transformed label
# 	dtype: float32
# 	shape: (4, 400, 400)
# 	min: -1.0
# 	mean: 3.8032727241516113
# 	max: 112.0

# %%
fig, axs = plt.subplots(1,2)
#axs[0].imshow(raw[z_slice])
axs[0].imshow(raw[0])
axs[1].imshow(t_raw[0])
fig.set_size_inches(15,7)

# %%
fig,axs = plt.subplots(2,4)
axs[0,0].imshow(jview.random_labeling(label[0], start_label=1, min_color = 100))
axs[0,1].imshow(label[1])
axs[0,2].imshow(label[2])
axs[0,3].imshow(label[3])
axs[1,0].imshow(jview.random_labeling(t_label[0], start_label=1, min_color = 100))
axs[1,1].imshow(t_label[1])
axs[1,2].imshow(t_label[2])
axs[1,3].imshow(t_label[3])
fig.set_size_inches(24,10)

# %%
fig,axs = plt.subplots(1,4)
axs[0].imshow(jview.random_labeling(flow[:,:,0], start_label=1, min_color = 100))
axs[1].imshow(flow[:,:,1])
axs[2].imshow(flow[:,:,2])
axs[3].imshow(flow[:,:,3])
fig.set_size_inches(24,15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_46720/942571595.py in <module>
#       1 fig,axs = plt.subplots(1,4)
# ----> 2 axs[0].imshow(jview.random_labeling(flow[:,:,0], start_label=1, min_color = 100))
#       3 axs[1].imshow(flow[:,:,1])
#       4 axs[2].imshow(flow[:,:,2])
#       5 axs[3].imshow(flow[:,:,3])
#
# NameError: name 'flow' is not defined
